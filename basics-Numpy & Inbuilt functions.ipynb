# %%
import numpy as np

# %%
l=[1,2,3,4,5]
arr= np.array(l)

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
np.shape(arr)
# Out:
# (5,)

# %%
l1=[1,2,3,4,5]
l2=[1,4,2,6,3]
l3=[0,1,7,2,7]
arr1= np.array([l1,l2,l3])
np.shape(arr1)
# Out:
# (3, 5)

# %%
arr1.reshape(5,3)
# Out:
# array([[1, 2, 3],
#        [4, 5, 1],
#        [4, 2, 6],
#        [3, 0, 1],
#        [7, 2, 7]])

# %%
arr1.shape
# Out:
# (3, 5)
